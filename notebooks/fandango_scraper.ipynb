# %% [markdown]
# ## Resources
# * Web Scraping Tutorial: https://youtu.be/52wxGESwQSA
#     * Associated GitHub repo: https://github.com/paulproteus/python-scraping-code-samples
# * MechanicalSoup Tutorial: http://mechanicalsoup.readthedocs.io/en/stable/tutorial.html
# * BeautifulSoup4 Documentation: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# * Some Selenium stuff: http://stanford.edu/~mgorkove/cgi-bin/rpython_tutorials/Scraping_a_Webpage_Rendered_by_Javascript_Using_Python.php
# * Add chromedriver to path: https://youtu.be/dz59GsdvUF8
# * Fandango API: https://developer.fandango.com/docs/read/Fandango

# %%
import re
import os
import json
from time import time
from time import sleep
from datetime import datetime
import requests
import threading
import queue

from selenium import webdriver
from bs4 import BeautifulSoup

import mechanicalsoup as msoup
import lxml

# %% [markdown]
# ## Selenium Solution (slow, but effective)

# %%
def params_to_url_string(params, url_base):

    params_string = "&".join(["%s=%s" % (key, params[key]) for key in params])
    url = "?".join([url_base, params_string])
    
    return url

def collect_showing_type_id(showing_type_id, description):
    
    metadata_dir = "../data/meta"
    file_name = "showing_type_ids.json"
    file_path = os.path.join(metadata_dir, file_name)
    
    if not os.path.exists(metadata_dir):
        os.makedirs(metadata_dir)
        
    showing_type_ids = {}
    
    if os.path.exists(file_path):
        with open(file_path, "r") as fp:
            showing_type_ids = json.load(fp)
        
    if showing_type_id not in showing_type_ids:
        showing_type_ids[showing_type_id] = description
        with open(file_path, "w") as fp:
            json.dump(showing_type_ids, fp)
    
    return showing_type_ids

def get_movie_info(url_base, params, print_confirmation=False):
    '''
    Get movie times for selected theater and movie
    '''
    
    movie_info = {
        "dropdowndates": None,
        "showing_type_ids": None,
        "movie_title": None,
        "theater_name": None,
        "error": None
    }
    
    response = requests.get(url = url_base, params = params)
    content = response.content.decode("utf-8")
    match = re.search(r"var dropdowndates = ({[\s\S]+]})\/\/\]\]", content)
    dropdowndates = json.loads(match.group(1)) if match else None
    
    if not dropdowndates:
        try:
            soup = BeautifulSoup(content, "html.parser")
            movie_info["error"] = soup.find("div", class_="errorHeaderMessage").text.strip()
            return movie_info
        except:
            movie_info["error"] = "UNKNOWN ERROR"
            return movie_info
    
    for date in dropdowndates:
        for item in dropdowndates[date]:
            description = item["Key"]
            showing_type_id = item["Times"][0].split("_")[1]
            showing_type_ids = collect_showing_type_id(showing_type_id, description)
    
    match = re.search(r'<h3 id="movieTitle">([\s\S]+?)</h3>', content)
    movie_title = match.group(1) if match else "movie_title_unknown"
    movie_title = re.sub(r"[*.\"\/\\\[\]:;|=,\!]", "_", movie_title).strip(" _")
    
    match = re.search(r'<h2 id="theaterName">([\s\S]+?)</h2>', content)
    theater_name = match.group(1) if match else "theater_name_unknown"
    theater_name = re.sub(r"[*.\"\/\\\[\]:;|=,\!]", "_", theater_name).strip(" _")
    
    movie_info = {
        "dropdowndates": dropdowndates,
        "showing_type_ids": showing_type_ids,
        "movie_title": movie_title,
        "theater_name": theater_name,
        "error": None
    }
    
    return movie_info

def click_through(url, movie_date, movie_time, op_sys="win", browser=None):

    page_info = {
        "source": None,
        "error": None
    }
    
    chromedriver_path = {
        "win": "../webdriver/chromedriver.exe",
        "linux": "../webdriver/chromedriver_linux64"
    }
    
    if browser:
        
        try: 
            # Click "Select new showtime"
            browser.find_element_by_xpath("//*[@id='movieTicketSummary']/div[3]/ul[2]/li[2]/p/a").click()
        except:
            browser.close()
            browser = webdriver.Chrome(chromedriver_path[op_sys])
            browser.get(url = url)
    
    else:
        browser = webdriver.Chrome(chromedriver_path[op_sys])
        browser.get(url = url)
    
    browser.find_element_by_xpath("//*[@id='ShowDateDropDownList']/option[@value='%s']" % movie_date).click()
    browser.find_element_by_xpath("//*[@id='ShowTimeDropDownList']/optgroup/option[@value='%s']" % movie_time).click()
    
    try:
        browser.find_element_by_xpath("//select[@name='AreaRepeater$ctl00$TicketRepeater$ctl00$quantityddl']/option[@value='1']").click()
    
    except:
        page_info["error"] = browser.find_element_by_class_name("errorHeaderMessage").text + "\n"
        return browser, page_info
    
    browser.find_element_by_id("NewCustomerCheckoutButton").click()
    
    try:
        browser.find_element_by_xpath("//*[@id='completePurchaseButton']")
        page_info["error"] = "This showing does not support reserved seating.\n"
        return browser, page_info
    
    except:
        page_info["source"] = browser.page_source
    
    return browser, page_info

def find_and_parse_seat_tags(source):
    
    seats = None
    error = None
    
    soup = BeautifulSoup(source, "html.parser")
    auditorium = soup.find("h2", id="auditoriumInfo").text.strip()
    seat_tags = soup.findAll(name = "div", attrs = {"class": re.compile(".*Seat"), "id": re.compile(".*")})
    
    if seat_tags:
        
        a = "availableSeat"
        u = "unavailableSeat"
        
        seats_raw = [[seat["id"], *seat["class"]] for seat in seat_tags]
        seats = [[x[0], x[1], "A" if x[-1] == a else "U" if x[-1] == u else "R"] for x in seats_raw]
        
    else:
        
        error = soup.find(name = "div", attrs = {"class": "errorHeaderMessage"}).get_text(strip = True)
        
        if not error:
            error = "Seating chart not found."
    
    seat_info = {
        "seats": seats,
        "auditorium": auditorium,
        "error": error
    }
    
    return seat_info

def get_paths(params, movie_info, movie_datetime):
    
    data_dir = "../data/movies/%s/%s - %s" % (movie_info["movie_title"], params["tid"], movie_info["theater_name"])
    data_file = os.path.join(data_dir, "%s.txt" % movie_datetime)
    log_file = os.path.join(data_dir, "%s.log" % movie_datetime)
    
    paths = {
        "data_dir": data_dir,
        "data_file": data_file,
        "log_file": log_file
    }
    
    return paths

def write_log(event, log_time, log_text_dict, log_file):
    
    with open(log_file, "a+") as f:
        log_text = "%s -%s" % (log_time, log_text_dict[event])
        f.write(log_text)
        return log_text

def write_data(browser, data, data_dir, data_file, log_text_dict, log_file, finish=False):
    
    log_time = str(datetime.now())
    
    seat_config = data["seat_config"]
    seat_reserv = data["seat_reserv"]
    auditorium = seat_config["auditorium"]
    
    img_dir = "../images/%s/%s" % (data_dir.split("/")[-1], auditorium)
    img_name = "%s.png" % auditorium
    img_path = "%s/%s" % (img_dir, img_name)
    
    if not os.path.exists(img_path):
        
        if not os.path.exists(img_dir):
            os.makedirs(img_dir)
        
        browser.set_window_size(1080, 1080)
        element = browser.find_element_by_xpath("//*[@id='seatpickerPage']")
        browser.execute_script("return arguments[0].scrollIntoView(true);", element)
        browser.save_screenshot(img_path)
    
    if not os.path.exists(data_file):
        
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)
        
        with open(data_file, "w") as f:
            f.write(str(seat_config) + "\n")
            f.write(str([log_time, seat_reserv]) + "\n")
            return write_log("start", log_time, log_text_dict, log_file)

    else:
        
        with open(data_file, "a+") as f:
            
            f.seek(0)
            saved_seat_config = f.readline().strip("\n")
            
            if saved_seat_config.strip("\n") != str(seat_config):
                return write_log("error_seat_config", log_time, log_text_dict, log_file)
            
            else:
                f.write(str([log_time, seat_reserv]) + "\n")
                return write_log("finish" if finish else "append", log_time, log_text_dict, log_file)

# %%
def get_seating_chart_and_write(movie_date, 
                                movie_time_full,
                                params,
                                movie_info,
                                url_base,
                                log_text_dict,
                                op_sys="win",
                                browser=None):

    skip = False
    
    [movie_time, showing_type_id] = movie_time_full.split("_")
    movie_datetime = datetime.strptime("%s %s" % (movie_date, movie_time), "%m/%d/%Y %I:%M %p")
    movie_datetime_formatted = movie_datetime.strftime("%Y-%m-%d_%H%M") + "_%s" % showing_type_id
    description = movie_info["showing_type_ids"][showing_type_id]

    delta = movie_datetime - datetime.now()
    finish = False
    if delta.total_seconds() < 60 * 8:
        finish = True

    url = params_to_url_string(params, url_base)
    
    browser, page_info = click_through(url, movie_date, movie_time_full, op_sys, browser)

    if page_info["error"]:
#         print("  |-- Movie Time [%s] %s" % (movie_datetime, page_info["error"]))
        skip = True
        return skip, browser

    seat_info = find_and_parse_seat_tags(page_info["source"])

    seats = seat_info["seats"]
    auditorium = seat_info["auditorium"]
    
    if seat_info["error"]:
        print("  |-- Movie Time [%s] %s" % (movie_datetime, seat_info["error"]))
        skip = True
        return skip, browser
    
    seat_config = {
        "auditorium": auditorium,
        "description": description,
        "seats": [x[0] for x in seats],
        "seat_types": [x[1] for x in seats]
    }
    
    data = {
        "seat_config": seat_config,
        "seat_reserv": {
            "R": [i for i in range(len(seats)) if seats[i][2] == "R"], 
            "U": [i for i in range(len(seats)) if seats[i][2] == "U"]
        }
    }

    paths = get_paths(params, movie_info, movie_datetime_formatted)

    log_text = write_data(browser,
                          data, 
                          paths["data_dir"], 
                          paths["data_file"], 
                          log_text_dict, 
                          paths["log_file"], 
                          finish)

#     print("  |-- Movie Time [%s] %s" % (str(movie_datetime), log_text))
    
    return skip, browser

# get_seating_chart_and_write("7/6/2018", "11:30 am_6819668", params, url_base, log_text_dict, op_sys)

# %%
op_sys = "win"

url_base = "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx"

incredibles_params = {
    "tid": "AABFB",                # theater id
    "mid": "185805",               # movie id
    "from": "mov_det_showtimes"    # page navigated from
}

antman_params_digital_3d = {
    "tid": "AABTB",
    "mid": "212354",
    "from": "mov_det_showtimes"
}

antman_params_imax_3d = {
    "tid": "AABTB",
    "mid": "211343",
    "from": "mov_det_showtimes"
}

antman_params_standard = {
    "tid": "AABTB",
    "mid": "203801",
    "from": "mov_det_showtimes"
}

antman_params_amc_standard = {
    "tid": "AAUNU",
    "mid": "203801",
    "from": "mov_det_showtimes"
}

antman_params_amc_digital_3d = {
    "tid": "AAUNU",
    "mid": "212354",
    "from": "mov_det_showtimes"
}

antman_params_big_newport_std = {
    "tid": "AABFB",
    "mid": "203801",
    "from": "mov_det_showtimes"
}

antman_params_big_newport_digital_3d = {
    "tid": "AABFB",
    "mid": "212354",
    "from": "mov_det_showtimes"
}

all_params = [
    antman_params_digital_3d,
    antman_params_imax_3d,
    antman_params_standard,
    antman_params_amc_standard,
    antman_params_amc_digital_3d,
    antman_params_big_newport_std,
    antman_params_big_newport_digital_3d
]

log_text_dict = {
    "start": " START: Successfully retrieved seating data.\n",
    "append": " Successfully appended seating data.\n",
    "finish": " FINISH: Successfully appended seating data.\n",
    "error_seat_config": "----- ERROR: Inconsistent seating configuration.\n"
}

###### --------------------------------------------------------------- #####

# def iterate_through_movie_times(url_base, params, log_text_dict, ops_sys, browser=None): 

#     days_before = 2
    
#     movie_info = get_movie_info(url_base, params)

#     if movie_info["error"]:
#         print(params["tid"], params["mid"], "\n", movie_info["error"])
#         return browser
    
#     movie_times = movie_info["dropdowndates"]

#     for date in (date for date in movie_times if (datetime.strptime(date, "%m/%d/%Y") - datetime.now()).days < days_before):

#         for item in movie_times[date]:

#             for t in item["Times"]:

#                 skip, browser = get_seating_chart_and_write(date, 
#                                                             t, 
#                                                             params, 
#                                                             movie_info, 
#                                                             url_base, 
#                                                             log_text_dict, 
#                                                             op_sys, 
#                                                             browser)

#                 if skip:
#                     continue
    
#     return browser

# def loop_until(end_datetime, url_base, params, log_text_dict, op_sys, browser=None):
    
#     loop_num = 0
    
#     while datetime.now() < end_datetime:
        
#         if loop_num != 0:
#             print("[%s]" % str(datetime.now()), params["tid"], params["mid"], " - Loop %d begun" % loop_num)
        
#         browser = iterate_through_movie_times(url_base, params, log_text_dict, op_sys, browser)
        
#         loop_num += 1
        
#     print("Looping ceased at %s." % str(datetime.now()))
    
#     return


# t = {}

# for i in range(len(all_params)):

#     params = all_params[i]
    
#     kwargs = {
#         "end_datetime": datetime(2018, 7, 7, 23, 59, 59),
#         "url_base": url_base,
#         "params": params,
#         "log_text_dict": log_text_dict,
#         "op_sys": op_sys,
#         "browser": None
#     }
    
#     t[i] = threading.Thread(target = loop_until, kwargs = kwargs)
#     t[i].start()
    
###### --------------------------------------------------------------- #####

def collect_data(loop_num, loop_dt=None):

    days_before = 2
    
    browser = None
    loop_num += 1
    
    tic = datetime.now()
    
    try: 
        if loop_dt:
            print("[%s] - Loop %d begun. (Previous loop length: %.2f minutes)" % (str(tic), loop_num, loop_dt))
        else:
            print("[%s] - Loop %d begun." % (str(tic), loop_num))

        for params in all_params:

            movie_info = get_movie_info(url_base, params)

            if movie_info["error"]:
                print(params, "\n", movie_info["error"])
                venue_num += 1
                continue

            movie_times = movie_info["dropdowndates"]

            for date in (date for date in movie_times if (datetime.strptime(date, "%m/%d/%Y") - datetime.now()).days < days_before):

                for item in movie_times[date]:

                    for t in item["Times"]:

                        skip, browser = get_seating_chart_and_write(date, 
                                                                    t, 
                                                                    params, 
                                                                    movie_info, 
                                                                    url_base, 
                                                                    log_text_dict, 
                                                                    op_sys, 
                                                                    browser)

                        if skip:
                            continue

            browser.close()
            browser = None
        
        loop_dt = (datetime.now() - tic).total_seconds()/60
        
        return loop_num, loop_dt

    except:
        try:
            browser.close()
        except:
            pass
        print("\n>>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<\n")
        loop_dt = (datetime.now() - tic).total_seconds()/60
        
        return loop_num, loop_dt
    
    
def loop(start_hour = 7):
    
    loop_num = 0
    sleep_counter = 0
    loop_dt = None
    
    while True:
        
        if datetime.now().hour >= start_hour:
            loop_num, loop_dt = collect_data(loop_num, loop_dt)
            
        else:
            sleep_counter += 1
            if sleep_counter > 6:
                sleep_counter = 0
                print("[%s] sleeping until %d:00 . . ." % (str(datetime.now()), start_hour))
            sleep(5*60)
    
    return

# start_datetime = datetime(2018, 7, 8, 7, 0, 0)
# end_datetime = datetime(2018, 7, 8, 23, 59, 0)
# dt = (start_datetime - datetime.now()).total_seconds()

# print("Starting in %f seconds.\n" % dt)

# t = threading.Timer(dt, loop, kwargs = {"end_datetime": end_datetime})
# t.start()

loop(start_hour = 7)
# Out:
# [2018-07-12 18:47:34.265185] - Loop 1 begun.
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 19:00:08.582081] - Loop 2 begun. (Previous loop length: 12.57 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 19:12:04.287163] - Loop 3 begun. (Previous loop length: 11.93 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 11:30:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-12 19:23:26.670487] - Loop 4 begun. (Previous loop length: 11.37 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 19:34:00.986431] - Loop 5 begun. (Previous loop length: 10.57 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 19:45:40.907813] - Loop 6 begun. (Previous loop length: 11.67 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 19:45:56.044331] - Loop 7 begun. (Previous loop length: 0.25 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 19:57:39.658500] - Loop 8 begun. (Previous loop length: 11.73 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 20:08:57.703722] - Loop 9 begun. (Previous loop length: 11.30 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 20:19:27.970673] - Loop 10 begun. (Previous loop length: 10.50 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 20:19:46.922304] - Loop 11 begun. (Previous loop length: 0.32 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 20:30:17.815881] - Loop 12 begun. (Previous loop length: 10.51 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 20:40:36.397841] - Loop 13 begun. (Previous loop length: 10.31 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-12 20:51:30.344654] - Loop 14 begun. (Previous loop length: 10.90 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 21:02:21.940061] - Loop 15 begun. (Previous loop length: 10.86 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 21:13:53.284650] - Loop 16 begun. (Previous loop length: 11.52 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 21:25:42.562842] - Loop 17 begun. (Previous loop length: 11.82 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 21:25:53.567142] - Loop 18 begun. (Previous loop length: 0.18 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-12 21:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 21:37:08.825285] - Loop 19 begun. (Previous loop length: 11.25 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 21:49:08.137997] - Loop 20 begun. (Previous loop length: 11.99 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 21:59:13.200519] - Loop 21 begun. (Previous loop length: 10.08 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 22:09:12.121152] - Loop 22 begun. (Previous loop length: 9.98 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 22:20:09.194316] - Loop 23 begun. (Previous loop length: 10.95 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 22:22:50.086924] - Loop 24 begun. (Previous loop length: 2.68 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 22:32:37.191970] - Loop 25 begun. (Previous loop length: 9.79 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 10:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
#   |-- Movie Time [2018-07-14 10:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-12 22:42:22.970452] - Loop 26 begun. (Previous loop length: 9.76 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 22:52:26.738495] - Loop 27 begun. (Previous loop length: 10.06 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 23:00:08.362476] - Loop 28 begun. (Previous loop length: 7.69 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 23:09:21.363383] - Loop 29 begun. (Previous loop length: 9.22 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 23:13:55.018832] - Loop 30 begun. (Previous loop length: 4.56 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 23:23:05.059984] - Loop 31 begun. (Previous loop length: 9.17 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 23:33:01.905732] - Loop 32 begun. (Previous loop length: 9.95 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 23:40:12.836084] - Loop 33 begun. (Previous loop length: 7.18 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-12 23:42:06.150909] - Loop 34 begun. (Previous loop length: 1.89 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-12 23:51:35.887131] - Loop 35 begun. (Previous loop length: 9.50 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 00:31:14.942404] sleeping until 7:00 . . .
# [2018-07-13 01:06:14.946218] sleeping until 7:00 . . .
# [2018-07-13 01:41:14.950018] sleeping until 7:00 . . .
# [2018-07-13 02:16:14.952696] sleeping until 7:00 . . .
# [2018-07-13 02:51:14.955806] sleeping until 7:00 . . .
# [2018-07-13 03:26:14.957022] sleeping until 7:00 . . .
# [2018-07-13 04:01:14.960298] sleeping until 7:00 . . .
# [2018-07-13 04:36:14.964608] sleeping until 7:00 . . .
# [2018-07-13 05:11:14.968192] sleeping until 7:00 . . .
# [2018-07-13 05:46:14.971265] sleeping until 7:00 . . .
# [2018-07-13 06:21:14.973403] sleeping until 7:00 . . .
# [2018-07-13 06:56:14.977032] sleeping until 7:00 . . .
# [2018-07-13 07:01:14.977272] - Loop 36 begun. (Previous loop length: 9.65 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-13 07:14:29.668425] - Loop 37 begun. (Previous loop length: 13.24 minutes)
#   |-- Movie Time [2018-07-13 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# ...
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 18:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 15:59:18.163579] - Loop 85 begun. (Previous loop length: 13.83 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 15:59:29.290751] - Loop 86 begun. (Previous loop length: 0.19 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 16:00:04.878371] - Loop 87 begun. (Previous loop length: 0.59 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 21:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 16:12:46.092861] - Loop 88 begun. (Previous loop length: 12.69 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-13 16:25:05.451619] - Loop 89 begun. (Previous loop length: 12.32 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-13 16:36:28.758171] - Loop 90 begun. (Previous loop length: 11.39 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-13 16:47:45.453569] - Loop 91 begun. (Previous loop length: 11.28 minutes)
#   |-- Movie Time [2018-07-15 11:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-13 23:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-14 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 14:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 17:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
#   |-- Movie Time [2018-07-15 20:30:00] Sorry, there are not enough reserved seats available.  Try changing the quantity of seats you requested or select a different showtime.
# [2018-07-13 16:59:32.022878] - Loop 92 begun. (Previous loop length: 11.78 minutes)
# [2018-07-13 17:11:12.419316] - Loop 93 begun. (Previous loop length: 11.67 minutes)
# [2018-07-13 17:22:14.811109] - Loop 94 begun. (Previous loop length: 11.04 minutes)
#   |-- Movie Time [2018-07-14 14:30:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 17:33:05.233953] - Loop 95 begun. (Previous loop length: 10.84 minutes)
# [2018-07-13 17:43:49.052971] - Loop 96 begun. (Previous loop length: 10.73 minutes)
#   |-- Movie Time [2018-07-14 13:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 17:54:45.634009] - Loop 97 begun. (Previous loop length: 10.94 minutes)
# [2018-07-13 18:05:22.059228] - Loop 98 begun. (Previous loop length: 10.61 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 18:05:55.097951] - Loop 99 begun. (Previous loop length: 0.55 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 18:11:07.233730] - Loop 100 begun. (Previous loop length: 5.20 minutes)
# [2018-07-13 18:21:19.082858] - Loop 101 begun. (Previous loop length: 10.20 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 18:26:28.117697] - Loop 102 begun. (Previous loop length: 5.15 minutes)
#   |-- Movie Time [2018-07-15 21:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
#   |-- Movie Time [2018-07-14 11:30:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 18:37:06.050725] - Loop 103 begun. (Previous loop length: 10.63 minutes)
# [2018-07-13 18:47:15.847351] - Loop 104 begun. (Previous loop length: 10.16 minutes)
# [2018-07-13 18:57:44.405456] - Loop 105 begun. (Previous loop length: 10.48 minutes)
# [2018-07-13 19:07:59.600764] - Loop 106 begun. (Previous loop length: 10.25 minutes)
# [2018-07-13 19:18:08.307506] - Loop 107 begun. (Previous loop length: 10.15 minutes)
#   |-- Movie Time [2018-07-15 16:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 19:28:20.026406] - Loop 108 begun. (Previous loop length: 10.20 minutes)
# [2018-07-13 19:38:17.019442] - Loop 109 begun. (Previous loop length: 9.95 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 19:43:23.679187] - Loop 110 begun. (Previous loop length: 5.11 minutes)
# [2018-07-13 19:53:47.407376] - Loop 111 begun. (Previous loop length: 10.40 minutes)
# [2018-07-13 20:03:57.795685] - Loop 112 begun. (Previous loop length: 10.17 minutes)
# [2018-07-13 20:14:00.785147] - Loop 113 begun. (Previous loop length: 10.05 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 20:14:35.598982] - Loop 114 begun. (Previous loop length: 0.58 minutes)
# [2018-07-13 20:24:50.225656] - Loop 115 begun. (Previous loop length: 10.24 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 20:25:28.032634] - Loop 116 begun. (Previous loop length: 0.63 minutes)
#   |-- Movie Time [2018-07-15 18:50:00] We are temporarily unable to process your order for the theater selected. Fandango is currently working to correct this issue, please try again soon.
# [2018-07-13 20:35:59.235239] - Loop 117 begun. (Previous loop length: 10.52 minutes)
# [2018-07-13 20:45:38.712230] - Loop 118 begun. (Previous loop length: 9.66 minutes)
# [2018-07-13 20:56:05.171175] - Loop 119 begun. (Previous loop length: 10.44 minutes)
# [2018-07-13 21:10:53.276441] - Loop 120 begun. (Previous loop length: 14.80 minutes)
# [2018-07-13 21:25:09.699126] - Loop 121 begun. (Previous loop length: 14.27 minutes)
# [2018-07-13 21:41:57.948529] - Loop 122 begun. (Previous loop length: 16.80 minutes)
# [2018-07-13 21:52:10.875415] - Loop 123 begun. (Previous loop length: 10.22 minutes)
# [2018-07-13 22:02:38.713875] - Loop 124 begun. (Previous loop length: 10.46 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 22:10:23.142198] - Loop 125 begun. (Previous loop length: 7.74 minutes)
# [2018-07-13 22:20:15.768979] - Loop 126 begun. (Previous loop length: 9.88 minutes)
# [2018-07-13 22:30:01.601398] - Loop 127 begun. (Previous loop length: 9.76 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 22:34:26.566386] - Loop 128 begun. (Previous loop length: 4.42 minutes)
# [2018-07-13 22:43:52.631415] - Loop 129 begun. (Previous loop length: 9.43 minutes)
# [2018-07-13 22:53:18.636211] - Loop 130 begun. (Previous loop length: 9.43 minutes)
# [2018-07-13 23:02:54.091209] - Loop 131 begun. (Previous loop length: 9.59 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 23:12:28.168453] - Loop 132 begun. (Previous loop length: 9.57 minutes)
# [2018-07-13 23:21:46.686434] - Loop 133 begun. (Previous loop length: 9.31 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 23:21:56.938966] - Loop 134 begun. (Previous loop length: 0.17 minutes)
# [2018-07-13 23:31:21.154009] - Loop 135 begun. (Previous loop length: 9.40 minutes)
# [2018-07-13 23:40:37.182085] - Loop 136 begun. (Previous loop length: 9.27 minutes)
# [2018-07-13 23:49:42.997936] - Loop 137 begun. (Previous loop length: 9.10 minutes)
#
# >>>>>>>>>>>> Unknown error encountered. Re-starting process. <<<<<<<<<<<<
#
# [2018-07-13 23:58:37.649583] - Loop 138 begun. (Previous loop length: 8.91 minutes)

# %% [markdown]
# ---
# # Other
# ---

# %%
# soup = BeautifulSoup(source, "html.parser")
# print(soup.decode(pretty_print = True))

# %%
# tic = time()

# browser = msoup.StatefulBrowser()
# # my_url = "https://www.fandango.com/92612_movietimes"
# # my_url = "https://www.fandango.com/incredibles-2-185805/movie-times"
# # my_url = "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx?row_count=231470826&tid=AABFB&sdate=2018-07-05+21:30&mid=185805&from=mov_det_showtimes"

# base_url = "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx"

# showing_params = {
#     "row_count": "231470826",      # ???
#     "tid": "AABFB",                # theater id
#     "sdate": "2018-07-05+21:30",   # showing date
#     "mid": "185805",               # movie id
#     "from": "mov_det_showtimes"    # page navigated from
# }

# # response = browser.open(base_url, params = showing_params)
# # soup = BeautifulSoup(response.content, "html.parser")
# # dt = time() - tic
# # print("Time elapsed: %s s" % dt)
# response.content.decode("utf-8")

# %%
# showing_params = {
# #     "row_count": "231470826",      # ???
#     "tid": "AABFB",                # theater id
# #     "sdate": "2018-07-05+21:30",   # showing date
#     "mid": "185805",               # movie id
#     "from": "mov_det_showtimes"    # page navigated from
# }

# url_base = "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx"

# response = requests.get(url = url_base, params = showing_params)
# response

# %%
response.url

# %%
# content = response.content.decode("utf-8") 
# match = re.search(r"var dropdowndates = ({[\s\S]+]})\/\/\]\]", content)
# if match:
#     dropdowndates = json.loads(match.group(1))
# else:
#     print("No showing times found.")
    
# dropdowndates

# %%
# showing_params = {
# #     "row_count": "231470826",      # ???
#     "tid": "AABFB",                # theater id
# #     "sdate": "7/5/2018+21:30",   # showing date
#     "mid": "185805",               # movie id
#     "from": "mov_det_showtimes"    # page navigated from
# }

# browser = msoup.StatefulBrowser()
# msoup_response = browser.open(response.url)
# browser.select_form()
# # browser.select_form().print_summary()
# browser["ShowDateDropDownList"] = "7/12/2018"
# browser.submit_selected()
# browser["ShowTimeDropDownList"] = "9:15 pm_6819668"
# # browser.get_current_form().print_summary()

# %%
# soup = BeautifulSoup(msoup_response.content, "html.parser")
# print(soup.decode(pretty_print = True))

# %% [markdown]
# # Select 1 ticket to to view seat selection
# * `Adult: 1`
# * `Senior: 0`
# * `Child: 0`
#
# (Assume that we already have a ticket selection URL, e.g. "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx?row_count=231470826&tid=AABFB&sdate=2018-07-05+21:30&mid=185805&from=mov_det_showtimes")

# %%
# ticket_selection_url = "https://tickets.fandango.com/transaction/ticketing/express/ticketboxoffice.aspx?row_count=232344705&tid=AABTB&sdate=2018-07-12+21:15&mid=185805&from=mov_det_showtimes"

# %%
# browser = msoup.StatefulBrowser()
# msoup_response = browser.open(ticket_selection_url)
# form = browser.select_form()
# browser["AreaRepeater$ctl00$TicketRepeater$ctl00$quantityddl"] = "1"
# # soup = BeautifulSoup(t_response.content, "html.parser")
# # form.choose_submit("inputTotal")
# response_1 = browser.submit_selected()

# %%
# soup.button

# %%
# soup = BeautifulSoup(response_1.content, "html.parser")
# print(soup.decode(pretty_print = True))
